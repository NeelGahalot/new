# %%
# %cd Deeplab
# Deeplab/saved_models/100_percent_volume_inhouse_resized_0.5432411918859545.pth
# Out:
# /teamspace/studios/this_studio/Deeplab
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
print(os.getcwd())
# Out:
# /teamspace/studios/this_studio/Deeplab

# %%
# !python3 split_dataset.py --dataset_dir 'crf_sam_annotations_large'
# /teamspace/studios/this_studio/Deeplab/india_sam_dino_annotations

# %%
# !python3 split_dataset.py --dataset_dir 'pilot_annotations_eastafrica_haiti_freetown'

# %%
downstreamed_large = '/teamspace/studios/this_studio/Deeplab/saved_models/india_sam_dino_250_samples_0.8495187035894669.pth'
downstreamed_small = '/teamspace/studios/this_studio/Deeplab/saved_models/india_sam_dino_250_samples_0.8940880817269634.pth'
downstreamed_tuned = '/teamspace/studios/this_studio/Deeplab/saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8213798905479425.pth'

# %%
# !python3 leaf_train.py --model deeplabv3plus_mobilenet --custom_data_path "crf_sam_annotations_large/" --batch_size 4 --lr 0.12 --total_itrs 10000 --loss_type binary_dice --val_interval 50  --separable_conv   
# /teamspace/studios/this_studio/Deeplab/saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8213798905479425.pth
# Out:
# Device: cuda
# Dataset: custom, Train set: 1860, Val set: 496
# [!] Retrain
# Epoch 1, Itrs 10/10000, Loss=1.270395
# Epoch 1, Itrs 20/10000, Loss=1.171225
# Epoch 1, Itrs 30/10000, Loss=1.158787
# Epoch 1, Itrs 40/10000, Loss=1.156444
# Epoch 1, Itrs 50/10000, Loss=1.087996
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# 124it [00:07, 16.56it/s]
# Validation Loss: 0.705588
#
# Foreground Acc: 0.864146
# Precision: 0.764606
# Recall: 0.864146
# F1 Score: 0.811334
# IoU Foreground: 0.682559
# IoU Background: 0.896930
# Mean IoU: 0.789744
#
# [0.6825586295035073]
# [50]
# Model saved as saved_models/crf_sam_large_freetown_eastafrica_haiti_sam_threshold_95_without_prob0.6825586295035073.pth
# saved here.
# ...
# Epoch 1, Itrs 60/10000, Loss=1.084551
# Epoch 1, Itrs 70/10000, Loss=1.049040
# Epoch 1, Itrs 80/10000, Loss=1.056198
# Epoch 1, Itrs 90/10000, Loss=0.978865
# Epoch 1, Itrs 100/10000, Loss=1.012903
# ...

# %%
# !python3 binary_leaf_kl_updated.py --model deeplabv3plus_mobilenet --custom_data_path "crf_sam_annotations_large/" --batch_size 4 --lr 0.12 --total_itrs 10000 --loss_type kl_dice_combined --val_interval 50  --separable_conv   
# /teamspace/studios/this_studio/Deeplab/saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8213798905479425.pth
# Out:
# Device: cuda
# Dataset: custom, Train set: 1860, Val set: 496
# [!] Retrain
# Epoch 1, Itrs 10/10000, Loss=1.762195
# Epoch 1, Itrs 20/10000, Loss=1.600969
# Epoch 1, Itrs 30/10000, Loss=1.633991
# Epoch 1, Itrs 40/10000, Loss=1.548969
# Epoch 1, Itrs 50/10000, Loss=1.331846
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# 124it [00:07, 16.38it/s]
# Validation Loss: 0.729322
#
# Foreground Acc: 0.889402
# Precision: 0.716121
# Recall: 0.889402
# F1 Score: 0.793410
# IoU Foreground: 0.657564
# IoU Background: 0.880441
# Mean IoU: 0.769003
#
# [0.6575644882132871]
# [50]
# Model saved as saved_models/kl_check_temp_2_weighted.pth
# saved here
# ...
# Epoch 1, Itrs 60/10000, Loss=1.499390
# Epoch 1, Itrs 70/10000, Loss=1.454118
# Epoch 1, Itrs 80/10000, Loss=1.457877
# Epoch 1, Itrs 90/10000, Loss=1.348878
# Epoch 1, Itrs 100/10000, Loss=1.404372
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# ...

# %%
# !python3 binary_leaf_main.py --model deeplabv3plus_mobilenet --custom_data_path "crf_sam_annotations_large/" --batch_size 4 --lr 0.12 --total_itrs 10000 --loss_type binary_dice --val_interval 50  --separable_conv   
# /teamspace/studios/this_studio/Deeplab/saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8213798905479425.pth
# Out:
# Device: cuda
# Dataset: custom, Train set: 186, Val set: 50
# [!] Retrain
# Epoch 1, Itrs 10/10000, Loss=1.219968
# Epoch 1, Itrs 20/10000, Loss=1.211644
# Epoch 1, Itrs 30/10000, Loss=1.150467
# Epoch 1, Itrs 40/10000, Loss=1.040683
# Epoch 2, Itrs 50/10000, Loss=1.213698
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# 13it [00:00, 14.20it/s]
# Validation Loss: 0.415333
#
# Foreground Acc: 0.929049
# Precision: 0.832942
# Recall: 0.929049
# F1 Score: 0.878374
# IoU Foreground: 0.783126
# IoU Background: 0.921587
# Mean IoU: 0.852357
#
# [0.7831262504105422]
# [50]
# ...
# Epoch 2, Itrs 60/10000, Loss=1.220376
# ^C
# Traceback (most recent call last):
#   File "/teamspace/studios/this_studio/Deeplab/binary_leaf_main.py", line 596, in <module>
#     main()
#   File "/teamspace/studios/this_studio/Deeplab/binary_leaf_main.py", line 503, in main
#     labels = labels.to(device, dtype=torch.long)
# KeyboardInterrupt

# %%
# !python3 binary_leaf_kl_updated.py --model deeplabv3plus_mobilenet --custom_data_path "crf_sam_annotations_large/" --batch_size 4 --lr 0.12 --total_itrs 10000 --loss_type kl_dice_combined --val_interval 50  --separable_conv   
# /teamspace/studios/this_studio/Deeplab/saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8213798905479425.pth
# Out:
# Device: cuda
# Dataset: custom, Train set: 1860, Val set: 496
# [!] Retrain
# Epoch 1, Itrs 10/10000, Loss=1.761071
# Epoch 1, Itrs 20/10000, Loss=1.618937
# Epoch 1, Itrs 30/10000, Loss=1.670326
# Epoch 1, Itrs 40/10000, Loss=1.577848
# Epoch 1, Itrs 50/10000, Loss=1.338472
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# 124it [00:07, 16.17it/s]
# Validation Loss: 0.796973
#
# Foreground Acc: 0.914325
# Precision: 0.679277
# Recall: 0.914325
# F1 Score: 0.779467
# IoU Foreground: 0.638628
# IoU Background: 0.865583
# Mean IoU: 0.752105
#
# [0.6386279069071205]
# [50]
# Model saved as saved_models/kl_check_temp_2_weighted.pth
# saved here
# Model saved as saved_models/crf_sam_large_freetown_eastafrica_haiti_sam_threshold_95_with_prob_0.6386279069071205.pth
# ...
# Epoch 1, Itrs 60/10000, Loss=1.490427
# Epoch 1, Itrs 70/10000, Loss=1.459067
# Epoch 1, Itrs 80/10000, Loss=1.446378
# Epoch 1, Itrs 90/10000, Loss=1.329029
# ...

# %%
# !python3 binary_leaf_main.py --model deeplabv3plus_mobilenet --custom_data_path "crf_sam_annotations/" --batch_size 4 --lr 0.12 --total_itrs 10000 --loss_type binary_dice --val_interval 50  --separable_conv   
# /teamspace/studios/this_studio/Deeplab/saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8213798905479425.pth
# Out:
# Device: cpu
# Dataset: custom, Train set: 187, Val set: 50
# [!] Retrain
# Epoch 1, Itrs 10/10000, Loss=0.616262
# Epoch 1, Itrs 20/10000, Loss=0.558123
# Epoch 1, Itrs 30/10000, Loss=0.557548
# Epoch 1, Itrs 40/10000, Loss=0.576444
# Epoch 2, Itrs 50/10000, Loss=0.589402
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# 13it [00:13,  1.05s/it]
# Validation Loss: 0.628057
#
# Foreground Acc: 1.000000
# Precision: 0.237518
# Recall: 1.000000
# F1 Score: 0.383862
# IoU Foreground: 0.237518
# IoU Background: 0.000000
# Mean IoU: 0.118759
#
# [0.23751792907714844]
# [50]
# Model saved as saved_models/crf_sam_large_freetown_eastafrica_haiti_sam_threshold_970.23751792907714844.pth
# saved here.
# ...
# Epoch 2, Itrs 60/10000, Loss=0.538243
# ^C

# %%
# !python3 binary_leaf_main.py --model deeplabv3plus_mobilenet --custom_data_path "crf_sam_annotations/" --batch_size 8 --lr 0.12 --total_itrs 10000 --loss_type binary_dice --val_interval 50  --separable_conv   
# /teamspace/studios/this_studio/Deeplab/saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8213798905479425.pth
# Out:
# Device: cuda
# Dataset: custom, Train set: 187, Val set: 50
# [!] Retrain
# Epoch 1, Itrs 10/10000, Loss=1.217085
# Epoch 1, Itrs 20/10000, Loss=1.078695
# Epoch 2, Itrs 30/10000, Loss=1.048480
# Epoch 2, Itrs 40/10000, Loss=1.048553
# Epoch 3, Itrs 50/10000, Loss=0.988182
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# 13it [00:01, 12.98it/s]
# Validation Loss: 0.584623
#
# Foreground Acc: 0.901423
# Precision: 0.881515
# Recall: 0.901423
# F1 Score: 0.891358
# IoU Foreground: 0.804009
# IoU Background: 0.933590
# Mean IoU: 0.868799
#
# [0.8040085468910082]
# [50]
# Model saved as saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8040085468910082.pth
# saved here
# ...
# Epoch 3, Itrs 60/10000, Loss=0.996446
# Epoch 4, Itrs 70/10000, Loss=0.971701
# Epoch 4, Itrs 80/10000, Loss=0.984593
# Epoch 4, Itrs 90/10000, Loss=0.986145
# Epoch 5, Itrs 100/10000, Loss=0.947798
# ...

# %%
# !python3 binary_leaf_main.py --model deeplabv3plus_mobilenet --custom_data_path "pilot_annotations_eastafrica_haiti_freetown/" --batch_size 16 --lr 0.01 --total_itrs 10000 --loss_type binary_dice --val_interval 50  --separable_conv --ckpt $downstreamed_small
#/teamspace/studios/this_studio/Deeplab/saved_models/base_sam_dino_india_tuned_freetown_eastafrica_haiti_0.8213798905479425.pth
# Out:
# Device: cpu
# Dataset: custom, Train set: 48, Val set: 183
# Model restored from /teamspace/studios/this_studio/Deeplab/saved_models/india_sam_dino_250_samples_0.8940880817269634.pth
# 46it [01:05,  1.42s/it]
#
# Foreground Acc: 0.920715
# Precision: 0.743458
# Recall: 0.920715
# F1 Score: 0.822647
# IoU Foreground: 0.698726
# IoU Background: 0.929017
# Mean IoU: 0.813871

# %%
# !python3 binary_leaf_main.py --model deeplabv3plus_mobilenet --custom_data_path "india_sam_dino_annotations_large/" --batch_size 16 --lr 0.01 --total_itrs 10000 --loss_type binary_dice --val_interval 50  --separable_conv
# Out:
# Device: cuda
# Dataset: custom, Train set: 3053, Val set: 814
# [!] Retrain
# Epoch 1, Itrs 10/10000, Loss=1.327401
# Epoch 1, Itrs 20/10000, Loss=1.142678
# Epoch 1, Itrs 30/10000, Loss=1.074712
# Epoch 1, Itrs 40/10000, Loss=1.067894
# Epoch 1, Itrs 50/10000, Loss=1.052424
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# 204it [00:11, 17.18it/s]
# Validation Loss: 0.785874
#
# Foreground Acc: 0.529455
# Precision: 0.863823
# Recall: 0.529455
# F1 Score: 0.656517
# IoU Foreground: 0.488668
# IoU Background: 0.884323
# Mean IoU: 0.686495
#
# [0.4886676694697532]
# [50]
# Model saved as saved_models/india_sam_dino_250_samples_0.4886676694697532.pth
# ...
# Epoch 1, Itrs 60/10000, Loss=1.042793
# Epoch 1, Itrs 70/10000, Loss=1.031934
# Epoch 1, Itrs 80/10000, Loss=1.014307
# Epoch 1, Itrs 90/10000, Loss=1.011342
# Epoch 1, Itrs 100/10000, Loss=1.011995
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# ...

# %%
import matplotlib.pyplot as plt

# Example lists of x and y values
x_values = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500, 1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000, 2050, 2100, 2150, 2200, 2250, 2300]
y_values = [0.4886676694697532, 0.6819128100575402, 0.7316776324091185, 0.7539703610134451, 0.7646733691379697, 0.7716763754696642, 0.780942755510218, 0.7891591265755157, 0.7947723249076609, 0.7976980095166158, 0.80284455982853, 0.7995927554839285, 0.8090232975237008, 0.8149058771937127, 0.8126718570911445, 0.8184854797204618, 0.8180831658173715, 0.8184463856799942, 0.8148966220170071, 0.8265067495056632, 0.8197575126821651, 0.8277434022634125, 0.8181608798921589, 0.8224712106517655, 0.8243492393484301, 0.8263397295553653, 0.8320330831656192, 0.8333233742814653, 0.8284184902499117, 0.8367651212779491, 0.8322137499776341, 0.8355160563935313, 0.8401478523183005, 0.8413897342847224, 0.8376933561199469, 0.8359486673807737, 0.8416792515202142, 0.8495187035894669, 0.8394195386637451, 0.8387325560736214, 0.8348048816371239, 0.8454194072776244, 0.8448191245663028, 0.8436732812052533, 0.8407730717110262, 0.8458518778740474]

# Plot the graph
plt.plot(x_values, y_values, marker='o', linestyle='-')
plt.xlabel('Iterations')
plt.ylabel('Foreground IOU')
plt.title('India_Sam_Dino_Annotations_Training_large')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Example lists of x and y values
x_values = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]
y_values = [0.77188253807654, 0.7945882804703195, 0.85439656783772, 0.8569383088344147, 0.8665472755014324, 0.8743193853513012, 0.8836554819011959, 0.8910747409996593, 0.8864961294929083, 0.8904289114374867, 0.8894175639405554, 0.8923611695996496, 0.8992382186585736, 0.9002104873381319, 0.8979438456833823, 0.9014707573662386, 0.9034829144092278, 0.9027885635096615, 0.8989919220038779]

# Plot the graph
plt.plot(x_values, y_values, marker='o', linestyle='-')
plt.xlabel('Iterations')
plt.ylabel('Foreground IOU')
plt.title('India_Sam_Dino_Annotations_Training_small')
plt.grid(True)
plt.show()

# %%
# !python3 binary_leaf_main.py --model deeplabv3plus_mobilenet --custom_data_path "freetown_sam_dino_annotations/" --batch_size 16 --lr 0.01 --total_itrs 10000 --loss_type binary_dice --val_interval 50  --separable_conv
# Out:
# Device: cuda
# Dataset: custom, Train set: 1184, Val set: 315
# [!] Retrain
# Epoch 1, Itrs 10/10000, Loss=1.327529
# Epoch 1, Itrs 20/10000, Loss=1.173729
# Epoch 1, Itrs 30/10000, Loss=1.072247
# Epoch 1, Itrs 40/10000, Loss=1.026006
# Epoch 1, Itrs 50/10000, Loss=1.020204
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# validation...
# 79it [00:04, 16.83it/s]
# Validation Loss: 0.899830
#
# Foreground Acc: 0.319595
# Precision: 0.815647
# Recall: 0.319595
# F1 Score: 0.459244
# IoU Foreground: 0.298064
# IoU Background: 0.853826
# Mean IoU: 0.575945
#
# [0.29806400034784947]
# [50]
# Model saved as saved_models/100_percent_volume_inhouse_resized_0.29806400034784947.pth
# ...
# Epoch 1, Itrs 60/10000, Loss=0.982481
# Epoch 1, Itrs 70/10000, Loss=0.943219
# Epoch 2, Itrs 80/10000, Loss=0.945691
# Epoch 2, Itrs 90/10000, Loss=0.936035
# Epoch 2, Itrs 100/10000, Loss=0.863783
# Model saved as saved_models/latest_deeplabv3plus_mobilenet_custom_os16.pth
# ...
